# %%
# -*- coding: utf-8 -*- 

import numpy 

from konlpy.tag import Okt
okt = Okt()

from konlpy.tag import Mecab
mecab = Mecab()

from khaiii import KhaiiiApi
api = KhaiiiApi()

import pandas as pd

n = input("typing the number of tsv file: ")

dataset = pd.read_csv("/Users/bobopack/Downloads/CS489-Team-14-repository-main 3/crawling_output/crawling_output_{0}.tsv".format(n)
, delimiter='\t', names = ['제목/댓글번호','기사작성시간/댓글본문','기사본문/좋아요','none/싫어요','none/답글수'])

datatable = dataset.values.tolist()


title = datatable[0][0]
article = datatable[0][2]
art = article.split("▶")
if len(art) > 1:
    icle = art[:-3]
    s = ""
    for t in icle:
        s += t
    article = s

comments = []
replys = []

comList = dataset['기사작성시간/댓글본문'].tolist()[0:]


for i in range(1,len(datatable)):
    line = datatable[i]
    if datatable[i-1][0] == datatable[i][0]:  #대댓글일때 (라인넘버, 대댓글본문)
        replys.append(line[:2])
    else:
        comments.append(line[:2]+line[4:])  #댓글일때 (라인넘버, 댓글본문, 답글갯수)
# Out:
# typing the number of tsv file: 1

# %%
comList = dataset['기사작성시간/댓글본문'].tolist()[1:]
comList
# Out:
# ['대한항공 빚 23조 ㄷㄷ',
#  '대한항공 기단이 아시아나보다 2배 이상이라 생각보다 많은 수치는 아닐겁니다 회사 규모에서 차이가 있기때문에요',
#  '대한항공이 아시아나보다 더하네.더한 거지가 덜거지인수하는격',
#  '비행기 리스로 돌리는데 다 부채로 잡힌다고 아저씨들아 한대당 4천억씩하는데 180대면 얼마야?',
#  'IFRS16 영향도 있고 산업 자체 특성도 고려해야지..코로나 직격탄 맞은 회사이기도 하고',
#  '기업 부채의 의미를 전혀 이해하지못하는 민노총 대깨문들 보소 ㅋㅋㅋㅋㅋㅋㅋ',
#  'asgh와 sier 말이 맞음 쟤네들 부채는 회계기준 변경 때문이고 기존 사업 특성이었음. 물론, 투자관점에서는 리스크지..특히나 imf 때 높은 부채로 기업들 무너졌던 것 생각하면 둘 합치고 나서는 구조조정이 불가피하다고 본다. 꼭 안력 구조조정이 아니라 비핵심사업 매각이나 중복자산 매각 등을 우선 하면 되겠지',
#  '아시아나 부채 22조 넘음',
#  '180대나마나 비행기수 비슷한 jal은 부채비율 50퍼인데?',
#  '아시아나 폐업시켜라... 뭘 인수하고 자시고 하냐...',
#  '내가 말한건 우리나라 항공사들 이야기임. 부채비율 낮은 곳 거의 없음',
#  '우리나라 항공사들 특성이 돈 없으니 자기자본 대신 운용리스로 항공사 운영했었고 그러니 수요 터질 때 대응했던 것고 있었음. 반대로 코로나 시기에 개박살 난거지. 그래도 항공산업은 기간산업이니 무너지지 않게 도와줘야 함',
#  '지들끼리 나누어먹기지 누가봐도 이건 밀실합의다',
#  '빚이 저만큼 많은데 오너일가는 잘산다는게 정말 아이러니지',
#  '비행기도 부채로 잡혀서 그럼 도라이야',
#  'ㄴ 비행기 빚은 회사빚 아니냐??ㅋㅋㅋㅋ 도라이는 너네 너 뭐 땅콩이 가족이냐??',
#  '1억가지고 10억짜리 아파트사서 잘먹고 잘살던데요?',
#  '부채보다 자산이 많으니까 잘살지.',
#  '빚내서 상가 10채를 갖고있는데 세입자가 없다면 어찌되는거냐?? 거기에 새로 빚으로 7채짜리 갖고있는 회사를 인수합병한다고?? 상가 세입자가 없는 마당에 창고로 돌려서 겨우 목숨부지하고 있다. 독과점만들어서 유일한 국적기 항공사라는 이름달고 국민세금 갉아먹으며 공기업같은 조씨 사유회사를 만드는게 그들의 목표아니냐?',
#  '이런 큰사업을하는데 실사한번않한다고?',
#  '큰 돈 들어가는데 막 2~3주 만에 똘똘 말아 쳐 넣어  이 나라 항공 전문가들은 허깨비냐?',
#  '기자도 정부 돈 받고 기사쓰나??',
#  '어디서 이름을 마음대로 바꾸노 기자. 대한항공이다. 망하는회사 이름은 꺼라 부정탄다',
#  '아시아나가 전라도 기업이니까 저딴 말도 안되는 특혜를 받는거야. 조만간 대한항공도 파산법원 문을 두드릴거다.',
#  '혈세투입하는데 국민들의견은 개무시군',
#  '세금으로 재벌 똥 닦아주는 이번 밀실야합을 규탄한다. 개인적으로 통합에 반대하지 않는다 다만 그 방법에 있어서 한진칼의 지분경쟁을 이용한 더러운 산업은행을 행위에 분노한다.',
#  '맞다 요즘 세상에 재벌을 맹목적으로 시러할 사람이 어딧나. 다만 이상한 일이 벌어지면 분노한다기회는 평등하고 과정은 공정하고 결과가 정의롭다고 햇는데 완전 반대거든',
#  '주주들이 싫다고 하는데 정부가 뭔 권리로 합친다고 결정을 하냐?정부는 지난 11월 16일 산업경쟁력 강화 관계장관회의를 열고 대한항공과 아시아나항공을 합치기로 했다.',
#  '아직 확정된거아니지않나? 이렇게 여론 몰이하지마라... 이런 기사들 흘리고 유야무야 은근슬쩍 통합하지말자.',
#  '망한기업떠안는것도 이상한데이름도 바꾸는거니?',
#  '기사 잘써라',
#  'ㅋㅋㅋ  정권 바뀌면 그때는 전정권에서 한거라 나몰라라 할 정부 결국 세금걷어서 싸가지 없는 집구석 구제해주는 꼴 차라리 대표를 새인물로 교체하는게 낫지안을까? 아님 아시아나 없애고 그돈 복지나 집값이나 잡아줘라.',
#  '조원태. 음주운전도 했고, 무슨이유였는지 학사도 반납하지 않았나. 이런 사람이 항공사오너라니',
#  '노조는 몇개냐 찬성한다는 노조는 모냐',
#  '원태 똘마니들 찬성하죠!',
#  '코리아나 항공?? 지들끼리 신났네. 아시아나 혼자 파산해야한다.',
#  '한진에서 쫄리는지 겁나 언플하네나랏돈으로 아시아나 먹는 특혜주려고 두리뭉실 넘어가려다 걸리는게 많지?',
#  '하이고 모지리들 비행기 대부분 리스라 부채로 잡혀요',
#  '원래 은행은 재벌편',
#  '산은 이동걸이 쇼하는거다, 부채만 합쳐서 34조인데 국민혈세 투입하겠다고 하는거',
#  '총수일가를 도와야지  그럼 아시아나 망하게 하니 박용진 ᆢ그럼 다른곳과 합병해봐  누가 적자난 항공 처 떠안을 기업 어딨나 ᆢ나라에서 적자이시아나 살리는조건으로 빅딜 처하는거지 누가 모르니  ㆍ대한항공이 더힘들어 모르면 가민히나 있지 박ᆢ 박은 요즘 말이 엄청많아 ᆢ입닫고 좀살지 남극이랑 계모아라',
#  '산은은 살고, 대항은 죽고, 국민은 이러나 저러나 죽겠구나',
#  '아 그냥 아시아나 걸르지;',
#  '조원태는 깜이 아니다, 합치고 나중에 조원태 팽~당하고 누구에게 갈까?',
#  '하지마라하면 좀 하지마',
#  '아시아나살리자고 대한항공까지 망쳐버리는',
#  '왜 꼭 대한항공이어야 하는가? 아시아나 제대로 실사하고 제값주고 사려는 곳도 많다던데',
#  "놀리듯 말하는 '코리아나'라는 단어를 기사제목으로 쓰다니ㅡㅡ 기자 제정신인가???",
#  '다 아는 내용 또 쓰냐?',
#  '통합반대!!',
#  '대한항공이여야지 무슨 코리아나냐 ㅡㅡ아시아나는 없어져야할 회사지',
#  '지금 상황에서 실업자 더 늘면 더 큰 재앙이죠 코리아나 항공 좋네  땅콩한테만 안가면 된다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '코리아나에서 웃었닼...자존심상해',
#  '국가가 뒷배  바주나? 구조조정을 확 하고 해도 될까말깐데,  구조조정없이 한다고?  세금이 남아도나?',
#  '밑빠진독에 물붙기 시작이네',
#  '오천억정도몀 유상증자한다고 해도 개미들 벌때같이 달려들꺼 같은디 고작 그거가지고 뭔 생색을 그리도 내냐',
#  '그냥  우리말  대한항공. 영문  코리아에어.  진에어  에어부산  에어서울은 우리말  서울항공   영문   서울에어로하세요.',
#  '미쳤네. 아직 결론 난게 아무것도 없는데 이렇게 해도 되나모르겠네요',
#  '대한항공이 인수하는데왜 쓰러져가는 회사이름을 같이 넣어요?기자님아!',
#  '아부지가 키워논 그룹 자식이 말아먹는구나..경영권 유지가뭐길래 독배를마시려고하는가..',
#  '한진은 아시아나 인수 포기하고 손떼라',
#  '그래서 한다는거야 만다는거야...',
#  '세금 = 재벌들 국개의원들 똥닦아주는 눈먼 돈',
#  '손에 손잡고~~벽을 넘어서~~~코리아나',
#  '비행기 현금주고 못사요빛내서 사는게 맞아요',
#  '시 ㅂㅏ ㄹ ㅜㅜㅠ정부 생각없는듯 하',
#  '예전 하나은행의  론스타  밀어주기식으로 누이좋고 매부 좋은격 되는거 아냐?  골치덩어리 떠넘겨좋구, 뒷돈받아 더 좋구, 한진은 명실상부 대마불사가 되기에 걔들도 좋구.  국민들 세금만 꼬라박는 격이될거 같은데,',
#  '대한아시나요항공',
#  '이씨 아이씨  증자참여 하는돈이 당신돈이가?꼬롭한시키',
#  '아시아나를 왜 대한항공에 앵기냐?????',
#  '10년 뒤... 다규 만들어 지고... 15년두 영화블랙머니 & 블랙 플라잉',
#  '코리아나항공? 80년대 갬성인가요',
#  '살릴거면 바로 대한항공으로 들어가지 뭔 한진칼에 투자해서 다시 내리냐 한국 특 - 윗놈들 챙겨주기 계단식 수수료충들 오지게 많음 한진칼에서 내릴때 또 나눠먹고 대한항공에서 또 나눠먹고 지들끼리 나랏돈으로 보너스챙기기',
#  '대단한 경영이네~~~~영끌 빛항공 그 많은돈 어디다 썻나 짚어서 책임지게 해라 세금 쓰지말고~~',
#  '적당히해라진짜',
#  '기사 참 자극적이네...',
#  '존나 골때리는게 부채 12조짜리 회사 인수못해서 안달난게 대한항공이라는점임, 가만보면 아시아나항공은 존나 느긋한데경영권때문에 개 쫄리니까 똥마려운 강아지ㅅㄲ 마냥 감정팔이에 10만일자리 운운하며 지가 더 급해 아주 ㅋㅋㅋㅋㅋ',
#  '가처분신청 기각도 안 되었는데 이런 기사를 쓰다니 완전 쓰레기임',
#  '회사는 빚더미인데 관련인들은   잘먹잘산다 니들이다 해먹고있군',
#  '뭐하는짓니냐? 어느놈이 주동자냐? 세금으로 부도덕한 한진그룹 밀어주는게? 자유로운 자본시장에 왜 정부가 끼여드노? 당장 그만두지 못할까?',
#  '대한항공 직원들 개시아나 직원들한테 욕하고 갑질해도 쌉인정 ~',
#  '살다 살다 조현아를 응원하게 될줄이야...']

# %%
dataset
# Out:
#                                제목/댓글번호  \
# 0    트럼프, 대선 불복 투쟁 12월 14일에 끝낸다 [특파원+]
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1
# ..                                 ...
# 165                                 92
# 166                                 93
# 167                                 93
# 168                                 94
# 169                                 94
#
#                                            기사작성시간/댓글본문  \
# 0                                  2020.11.27. 오전 9:45
# 1                            민주당 후보는 백악관대신 깜빵으로 직행할 것임
# 2                                              의지의 미쿡인
# 3                                              출처는 유튜브
# 4            바이든이 깜빵안가고 백악관가면 이제 댓글안달거요? 그 정도는 걸어야지.ㅉㅉ
# ..                                                 ...
# 165  결과는 아직 안나왔어요 바이든과 민주당 주류미디어들이 그냥 억지 부리고 있고요실제 ...
# 166                                     미합중국 대통령 조 바이든
# 167                                   🎉🎊🎉🎊🎉🎊🎉🎊🎉🎊🎉🎊🎉🎊🎉🎊
# 168  사태파악도 못하는 정신이상자..언제까지 불복타령이냐？당선시 큰소리 뻥뻥 쳐놓고 꼬라...
# 169                                                 우민
#
#                                               기사본문/좋아요  none/싫어요  none/답글수
# 0    도널드 트럼프 미국 대통령. AFP연합뉴스 도널드 트럼프 미국 대통령이 오는 12월...       NaN       NaN
# 1                                     8.24317398347295  5.491853      19.0
# 2                                                    0  0.000000       NaN
# 3                                    4.459431618637297  0.000000       NaN
# 4                                    4.321928094887363  0.000000       NaN
# ..                                                 ...       ...       ...
# 165                                                  0  0.000000       NaN
# 166                                  2.321928094887362  3.321928       1.0
# 167                                                  0  0.000000       NaN
# 168                                                  0  2.584963       1.0
# 169                                                  0  0.000000       NaN
#
# [170 rows x 5 columns]

# %%
#okt
# def get_morphs(text):
#     tags = okt.pos(text, norm='True', stem='True')
#     l = [] 
#     for words in tags:  
#         l.append(words[0])
#     return l

# def get_nouns(text):
#     key = ["Noun"] 
#     tags = okt.pos(text, norm='True', stem='True')
#     l = [] 
#     for words in tags:  
#         if words[1] in key:
#             l.append(words[0])
#     return l
    
# def num_pos(text):
#     tags = okt.pos(text, norm='True', stem='True')
#     return len(tags)

# %%
#mecab
def get_morphs(text):
    tags = mecab.pos(text)
    l = [] 
    for words in tags:  
        l.append(words[0])
    return l

def get_nouns(text):
# 일반명사,고유명사
    key = ["NNG", "NNP"] 
    tags = mecab.pos(text)
    l = [] 
    for words in tags:  
        if words[1] in key:
            l.append(words[0])
    return l
    
def num_pos(text):
    tags = mecab.pos(text)
    return len(tags)

# %%
# #khaiii

# # 일반명사,고유명사
# key = ["NNG", "NNP"] 

# for reply in cat_list:
    
#     morphs = []
#     for word in api.analyze(reply):
#         for morph in word.morphs:
#             morphs.append((morph.lex, morph.tag))
#     tags = morphs

#     print(tags)
# #     l = [] 
# #     for words in tags:  
# #         if words[1] in key:
# #             l.append(words)
# #     print(l)

# %%
# 명사개수
def num_naive(text):
    nouns = get_nouns(text)
    return len(nouns)

# 명사종류개수
def num_only(text):
    nouns = get_nouns(text)
    return len(set(nouns))

# 본문포함된 명사개수
def num_naive_article(article, text):
    article_nouns = get_nouns(article)
    nouns = get_nouns(text)
    real_nouns = []
    for noun in nouns:
        if noun in article_nouns:
            real_nouns.append(noun)
    return len(real_nouns)

# 본문포함된 명사종류개수
def num_only_article(article, text):
    article_nouns = set(get_nouns(article))
    nouns = set(get_nouns(text))
    inter = nouns.intersection(article_nouns)
    return len(inter)



# processed comments and replys
proc_comments = []
# proc_replys = []

for comment in comments:
    content = comment[1]
    processing = comment + [num_pos(content), 
                            num_naive(content), 
                            num_only(content), 
                            num_naive_article(article, content), 
                            num_only_article(article, content)]
    proc_comments.append(processing)
# for reply in replys:
#     content = reply[1]
#     processing = comment + [num_pos(content), num_naive(content), num_only(content), num_naive_article(article, content), num_only_article(article, content)]
#     proc_replys.append(processing)

# %%
# Jaccard Similarity
def jac_sim(article, text):
    article = set(get_morphs(article))
    comment = set(get_morphs(text))
    inter = comment.intersection(article)
    uni = comment.union(article)
    return len(inter)/len(uni)

def nonset_jac_sim(article, text):
    article = get_morphs(article)
    comments = get_morphs(text)
    inter = []
    for comment in comments:
        if comment in article:
            inter.append(comment)
    uni = set(comments).union(set(article))
    return len(inter)/len(uni)

def noun_jac_sim(article, text):
    article_nouns = set(get_nouns(article))
    nouns = set(get_nouns(text))
    inter = nouns.intersection(article_nouns)
    uni = nouns.union(article_nouns)
    return len(inter)/len(uni)

def nonset_noun_jac_sim(article, text):
    article_nouns = get_nouns(article)
    nouns = get_nouns(text)
    real_nouns = []
    for noun in nouns:
        if noun in article_nouns:
            real_nouns.append(noun)
    uni = set(nouns).union(set(article_nouns))
    return len(real_nouns)/len(uni)

    
# revised rated comments and replys    
rated_comments = []
# rated_replys = []

for comment in comments:
    content = comment[1]
#     n = num_pos(content)
    rating = comment + [num_pos(content),
                        num_naive_article(article, content) / (num_naive(content)+1), 
                        num_only_article(article, content) / (num_only(content)+1), 
                        jac_sim(article, content), 
                        nonset_jac_sim(article, content), 
                        noun_jac_sim(article, content), 
                        nonset_noun_jac_sim(article, content)]
    rated_comments.append(rating)

    
    
# for reply in replys:
#     content = reply[1]
# #     n = num_pos(content)
#     rating = comment + [num_naive_article(article, content)/(num_naive(content)+1), 
#                         num_only_article(article, content)/(num_only(content)+1), 
#                         jac_sim(article, content), 
#                         nonset_jac_sim(article, content), 
#                         noun_jac_sim(article, content), 
#                         nonset_noun_jac_sim(article, content)]
#     rated_replys.append(rating)

# %%
   
# part for sklearn, similarity

from sklearn.feature_extraction.text import TfidfVectorizer

def tfid_vectorize(article, comment):
    sent = (article, comment)
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(sent) #문장 벡터화 진행
    idf = tfidf_vectorizer.idf_
    #print(dict(zip(tfidf_vectorizer.get_feature_names(), idf)))
    return tfidf_matrix

#Cosine_similarity

from sklearn.metrics.pairwise import cosine_similarity
def cos_sim(matrix):
    sim = cosine_similarity(matrix[0:1], matrix[1:2]) #첫번째와 두번째 문장 비교
    #array([[0.113]])
    return sim[0][0]

#Euclidean Distance or L2-Distance

from sklearn.metrics.pairwise import euclidean_distances
def euc_dis(matrix):
    sim = euclidean_distances(matrix[0:1], matrix[1:2])
    #array([[1.331]])
    return sim[0][0]

#L1-Normalization

import numpy as np
def l1_normalize(v):
    norm = np.sum(v)
    return v / norm
def nor_euc_dis(matrix):
    tfidf_norm_l1 = l1_normalize(matrix)
    sim = euclidean_distances(tfidf_norm_l1[0:1], tfidf_norm_l1[1:2])
    # array([[0.212]])
    return sim[0][0]

#Manhattan Similarity or  L1-Distance

from sklearn.metrics.pairwise import manhattan_distances
def manh_dis(matrix):
    sim = manhattan_distances(matrix[0:1], matrix[1:2])
    #array([[0.857]])
    return sim[0][0]
def nor_manh_dis(matrix):
    tfidf_norm_l1 = l1_normalize(matrix)
    sim = manhattan_distances(tfidf_norm_l1[0:1], tfidf_norm_l1[1:2])
    #array([[0.857]])
    return sim[0][0]

# similarity commnets

similarity_comments = []

for comment in comments:
    content = comment[1]
    tfidf_matrix = tfid_vectorize(article, content)
    #tfidf_matrix = tfid_vectorize(summary, content)
    similarity = comment + [cos_sim(tfidf_matrix), euc_dis(tfidf_matrix), nor_euc_dis(tfidf_matrix), manh_dis(tfidf_matrix), nor_manh_dis(tfidf_matrix)]
    similarity_comments.append(similarity)

# %%
print("Entire num of commnets is: {0}\n".format(len(comments)))
print(article)
# Out:
# Entire num of commnets is: 94
#
# 도널드 트럼프 미국 대통령. AFP연합뉴스 도널드 트럼프 미국 대통령이 오는 12월 14일 선거인단 투표에서 조 바이든 대통령 당선인이 승리하면 백악관을 떠날 것이라고 밝혀 대선 불복 투쟁 시한을 분명하게 밝혔다. 트럼프 대통령은 26일(현지시간) 추수감사절을 맞아 백악관에서 해외 장병들에게 연설한 뒤 대선 불복에 대한 자신의 입장을 기자들에게 밝혔다. 트럼프 대통령이 대선 이후 기자들과 문답을 진행한 것은 이번이 처음이다. 그의 이날 발언은 대선 패배 인정에 가장 가까운 것이라고 미국 언론이 평가했다. 그러나 트럼프 대통령은 선거인단 투표가 이뤄질 때까지는 ‘선거 조작’ 의혹을 제기하면서 소송전을 계속할 것으로 보인다.  트럼프 대통령은 선거인단이 바이든 당선인을 선출하면 어떻게 하겠느냐는 질문에 “승복하는 것은 매우 어려운 일이 될 것”이라며 “그들이 그렇게 한다면 실수하는 것”이라고 말했다. 그는 이어 백악관을 떠날 것이냐는 질문에 “분명히 나는 그럴 것이다”면서 “여러분도 이 점을 알고 있다”고 말했다.  트럼프 대통령은 이날도 이번 대선이 부정선거였기 때문에 그 결과를 수용할 수 없고, 사기투표가 없었다면 자신이 승리했을 것이라고 주장했다. 그는 “거대한 사기였고, 우리가 제3세계 국가와 같다”고 말했다. 그는 또 백악관에서 마지막 추수감사절을 어떻게 보낼지 묻는 말에 “처음일지, 마지막일지 말할 수 없다”면서 “두 번째 임기의 처음일 수도 있다”고 했다. 그는 또 “누구도 이번 선거가 보여주는 이런 종류의 사기를 보고 싶어하지 않는다”고 했다. 트럼프 대통령은 “바이든 정부 ‘아메리카 퍼스트’를 없애고 싶어 한다”면서 “나는 한 가지는 알고 있는데 조 바이든이 8000만표를 얻지 못했다”고 말했다.  트럼프 대통령은 내년 1월 5일 실시되는 조지아주의 상원 의원 결선 투표에서 공화당 후보를 지원하기 위해 현장에 갈 것이라고 밝혔다. 그는 “그곳 사람들은 우리가 도둑맞아 매우 실망해 있다”고 주장했다.  미국의 주별로 현재 개표 결과에 대한 인준 절차가 계속되고 있다. 각 주는 오는 12월 8일까지 개표 인준을 모두 마치고, 주별로 선거인단을 선정한다. 주 의회는 주별 개표 결과에 따라 승자에게 투표할 선거인단을 선출하지만, 일부 주는 선거인단이 반드시 승자에게 투표해야 한다는 의무 규정을 두지 않고 있다. 다만 주 의회가 그 주에서 승리한 후보를 지지하지 않는 선거인단을 선출하면 주지사가 별도의 선거인단을 구성해 선거인단 투표장에 보낼 수 있다. 주 의회와 주지사가 각각 다른 선거인단을 파견하면 미 연방 하원이 주지사가 보낸 선거인단을 그 주의 대표로 ‘우선하여’ 인정해야 한다고 연방 선거법에 규정돼 있다.  트럼프 대통령은 12월 14일 선거인단 투표가 있을 때까지 대선 불복 입장을 고수하겠다고 밝혔으나 오는 12월 8일에 사실상 대선 당선자가 확정된다고 뉴욕 타임스(NYT)가 지적했다. 각주의 주지사는 12월 8일까지 선거인단을 확정해 연방 의회에 통보해야 하고, 이때 선거인단의 인적 사항과 이들이 바이든과 트럼프 중 누구에게 투표할지 결정된다. 각 주는 12월 14일에 주별로 한 장소에서 선거인단 투표를 한다. 바이든 당선인은 대선 승리에 필요한 선거인단 숫자인 ‘매직 넘버 270명’을 넘어 306명의 선거인단을 확보했고, 트럼프 대통령은 232명을 확보하는 데 그쳤다.  조 바이든 미국 대통령 당선인. 윌밍턴 AP=연합뉴스 각 주가 선거인단 투표를 완료하면 연방 의회가 내년 1월 6일 개표를 한 뒤 그 결과를 공식 발표한다. 미국의 차기 대통령은 내년 1월 20일 취임한다. 바이든 당선인의 임기는 이날 정오에 시작된다.  트럼프 대통령은 대선 불복 소송에서 연전연패했으나 대표적인 경합 주인 펜실베이니아주에서 26일 공화당 소속 고법 판사의 판결로 부분적인 승리를 거뒀다. 펜실베이니아주는 이미 바이든 당선인의 승리한 개표 결과를 인준했으나 펜실베이니아주 고등법원의 패트리샤 맥컬로 판사가 주 정부에 개표 인증과 관련된 추가 절차를 중단하라는 명령을 내렸다. 맥컬로 판사는 27일 증거 조사를 위한 심리를 열 계획이다. 워싱턴 포스트(WP)에 따르면 맥컬로 판사는 2009년 공화당 소속으로 출마해 법관으로 임용됐다. 미국 연방법원 판사는 연방 상원의 인준을 거쳐 대통령이 임명하지만, 주 법원 판사는 주민투표나 주지사 임명을 통해 선발된다. 민주당이 이끄는 주 정부는 주 대법원에 상고했다.  트럼프 대통령 측의 선거 조작 규명을 위한 소송 지원을 위해 250만 달러 (약 28억 원)의 거액을 기부했던 투자회사 ‘에셜먼 벤처스 LLC’ 창립자 프레드 에셜먼은 자신이 낸 기부금을 돌려달라는 소송을 텍사스주 휴스턴의 연방법원에 냈다고 블룸버그 통신이 이날 보도했다. 그는 휴스턴에 있는 친 트럼프 단체인 ‘트루 더 보트(True the Vote)’ 기부금을 냈으나 아무런 성과가 없었으니 돈을 돌려달라고 했다. 이 단체는 4건의 소송을 냈다가 취하한 것으로 알려졌다.  워싱턴=국기연 특파원 kuk@segye.com    ⓒ 세상을 보는 눈, 세계일보

# %%
df0 = pd.DataFrame(comments, columns=['댓글번호','댓글본문','답글수'])
df0.head(10)
# Out:
#    댓글번호                                               댓글본문   답글수
# 0     1                                      대한항공 빚 23조 ㄷㄷ  12.0
# 1     2                          지들끼리 나누어먹기지 누가봐도 이건 밀실합의다   0.0
# 2     3                    빚이 저만큼 많은데 오너일가는 잘산다는게 정말 아이러니지   5.0
# 3     4                               이런 큰사업을하는데 실사한번않한다고?   1.0
# 4     5                                 기자도 정부 돈 받고 기사쓰나??   0.0
# ..  ...                                                ...   ...
# 57   58                가처분신청 기각도 안 되었는데 이런 기사를 쓰다니 완전 쓰레기임   0.0
# 58   59                 회사는 빚더미인데 관련인들은   잘먹잘산다 니들이다 해먹고있군   0.0
# 59   60  뭐하는짓니냐? 어느놈이 주동자냐? 세금으로 부도덕한 한진그룹 밀어주는게? 자유로운 ...   0.0
# 60   61                 대한항공 직원들 개시아나 직원들한테 욕하고 갑질해도 쌉인정 ~   0.0
# 61   62                            살다 살다 조현아를 응원하게 될줄이야...   0.0
#
# [62 rows x 3 columns]

# %%
df1 = pd.DataFrame(proc_comments, columns = ['댓글번호','댓글내용','답글수','pos길이',
                                             '명사개수','명사종류개수',
                                             '본문명사개수','본문명사종류개수'])

new_df1 = df1.sort_values(by='본문명사개수', ascending=False)

new_df1.head(10)
#new_df1
#df1
# Out:
#    댓글번호                                               댓글내용  답글수  pos길이  명사개수  \
# 18   19  지금 미국은 부정선거의 증거가 너무 많아서 바이든이 대통령되기는 커녕 감빵갈 기세다...  1.0    143    47
# 12   13  미국은 이미 청문회하고~ 경합주부터 해서 거이다 결과보류 판사들이 때렸던데..  결...  0.0    133    46
# 41   42  투쟁은 개뿔이나. 그 날짜에 대선이 끝난다. 정부와 기레기들이 이상한 언론에서 기사...  0.0    101    29
# 71   72  https://kr.theepochtimes.com/share/554053중국 관영...  0.0    133    53
# 63   64  트럼프가 이기고 있고 아직 270석이 안됐을 뿐이고 증거들과 증인들이 넘쳐나고 있고...  0.0    142    50
# 83   84  바지사장 바이든이 진짜 당선 되었다 치더라도 민주당 자체에서 제거될겁니다 그 다음이...  1.0    122    48
# 16   17  경악할만큼의 거대한 부정선거가 오래전부터 준비되어왔고 바이든, 민주당, 주류미디어,...  2.0    149    45
# 42   43  언론은 진실을 밝히기 위해 투쟁해야 하는데......왜 미국에서 발표되고 심리되는 ...  0.0    116    30
# 39   40  트럼프 후보가 선거 결과를 12월 8일에 수용 할 것이다. 그는 선거인단 선거에서 ...  0.0     69    16
# 15   16  우리나라 국민들 너무나 개돼지들이다..대법원에서 재검표시한인 6개월을 훌쩍 넘겨도 ...  0.0    146    39
#
#     명사종류개수  본문명사개수  본문명사종류개수
# 18      38      25        19
# 12      42      19        16
# 41      23      17        12
# 71      40      16        10
# 63      43      14        11
# 83      32      14         7
# 16      40      14        11
# 42      25      14        11
# 39      13      12         9
# 15      31      11        10

# %%
df2 = pd.DataFrame(rated_comments, columns = ['댓글번호','댓글내용','답글수','pos길이',
                                              '본문/전체명사','본문/전체명사종류', 
                                              '자카드','nonset자카드',
                                              '자카드명사','nonset자카드명사'])

new_df2 = df2.sort_values(by='본문/전체명사', ascending=False)

new_df2.head(10)

#new_df2
# Out:
#    댓글번호                                               댓글내용  답글수  pos길이  \
# 39   40  트럼프 후보가 선거 결과를 12월 8일에 수용 할 것이다. 그는 선거인단 선거에서 ...  0.0     69
# 17   18  선거인단이 투표를 못하니까 트럼프 저렇게 말한다 거다 ㅋㅋㅋㅋㅋ지금 경합주 전부다 ...  0.0     39
# 26   27  바보아냐? 온갖 소송으로 선거인단이 구성이 안되는데 구성을 전제로 한 결과승복에 바...  0.0     35
# 25   26  낙장불입?  기부했으니 끝? 아니지. 소송하고 싸운다고 돈 받아가서 취하하고 말았으...  0.0     41
# 92   93                                     미합중국 대통령 조 바이든  1.0      4
# 6     7                           트럼프는  백악관으로  바이든은   감옥으로  0.0      8
# 46   47                      트럼프야 개기라 트뽕놈들이응원한다  부정선거   히히  0.0     14
# 41   42  투쟁은 개뿔이나. 그 날짜에 대선이 끝난다. 정부와 기레기들이 이상한 언론에서 기사...  0.0    101
# 10   11  12월 14일이 지나면 투표 무효되는데 ㅋㅋㅋㅋ 즉, 트럼프는 기존 선거를 무효화시...  0.0     37
# 66   67  연방총무처(조달청) "바이든 당선인정 보도는 가짜뉴스, 대통령 선거의 실제 승자는 ...  0.0     30
#
#      본문/전체명사  본문/전체명사종류       자카드  nonset자카드     자카드명사  nonset자카드명사
# 39  0.705882   0.642857  0.085575   0.127139  0.047120     0.062827
# 17  0.700000   0.666667  0.034230   0.044010  0.031746     0.037037
# 26  0.666667   0.636364  0.049628   0.057072  0.036842     0.042105
# 25  0.600000   0.555556  0.039216   0.053922  0.026316     0.031579
# 92  0.600000   0.600000  0.007634   0.007634  0.015957     0.015957
# 6   0.600000   0.600000  0.015267   0.017812  0.015957     0.015957
# 46  0.571429   0.571429  0.017544   0.017544  0.021164     0.021164
# 41  0.566667   0.500000  0.093525   0.172662  0.060606     0.085859
# 10  0.555556   0.571429  0.059701   0.062189  0.021164     0.026455
# 66  0.555556   0.529412  0.044888   0.049875  0.046392     0.051546

# %%
df2 = pd.DataFrame(rated_comments, columns = ['댓글번호','댓글내용','답글수','pos길이',
                                              '본문/전체명사','본문/전체명사종류', 
                                              '자카드','nonset자카드',
                                              '자카드명사','nonset자카드명사'])

new_df2 = df2.sort_values(by='본문/전체명사종류', ascending=False)

new_df2.head(10)

#new_df2
# Out:
#    댓글번호                                               댓글내용  답글수  pos길이  \
# 17   18  선거인단이 투표를 못하니까 트럼프 저렇게 말한다 거다 ㅋㅋㅋㅋㅋ지금 경합주 전부다 ...  0.0     39
# 39   40  트럼프 후보가 선거 결과를 12월 8일에 수용 할 것이다. 그는 선거인단 선거에서 ...  0.0     69
# 26   27  바보아냐? 온갖 소송으로 선거인단이 구성이 안되는데 구성을 전제로 한 결과승복에 바...  0.0     35
# 6     7                           트럼프는  백악관으로  바이든은   감옥으로  0.0      8
# 92   93                                     미합중국 대통령 조 바이든  1.0      4
# 46   47                      트럼프야 개기라 트뽕놈들이응원한다  부정선거   히히  0.0     14
# 10   11  12월 14일이 지나면 투표 무효되는데 ㅋㅋㅋㅋ 즉, 트럼프는 기존 선거를 무효화시...  0.0     37
# 25   26  낙장불입?  기부했으니 끝? 아니지. 소송하고 싸운다고 돈 받아가서 취하하고 말았으...  0.0     41
# 66   67  연방총무처(조달청) "바이든 당선인정 보도는 가짜뉴스, 대통령 선거의 실제 승자는 ...  0.0     30
# 68   69                                   선거에 패했으면 조용히 꺼져라  0.0      6
#
#      본문/전체명사  본문/전체명사종류       자카드  nonset자카드     자카드명사  nonset자카드명사
# 17  0.700000   0.666667  0.034230   0.044010  0.031746     0.037037
# 39  0.705882   0.642857  0.085575   0.127139  0.047120     0.062827
# 26  0.666667   0.636364  0.049628   0.057072  0.036842     0.042105
# 6   0.600000   0.600000  0.015267   0.017812  0.015957     0.015957
# 92  0.600000   0.600000  0.007634   0.007634  0.015957     0.015957
# 46  0.571429   0.571429  0.017544   0.017544  0.021164     0.021164
# 10  0.555556   0.571429  0.059701   0.062189  0.021164     0.026455
# 25  0.600000   0.555556  0.039216   0.053922  0.026316     0.031579
# 66  0.555556   0.529412  0.044888   0.049875  0.046392     0.051546
# 68  0.500000   0.500000  0.005051   0.005051  0.005348     0.005348

# %%
df2 = pd.DataFrame(rated_comments, columns = ['댓글번호','댓글내용','답글수','pos길이',
                                              '본문/전체명사','본문/전체명사종류', 
                                              '자카드','nonset자카드',
                                              '자카드명사','nonset자카드명사'])

new_df2 = df2.sort_values(by='자카드', ascending=False)

new_df2.head(10)

#new_df2
# Out:
#    댓글번호                                               댓글내용  답글수  pos길이  \
# 18   19  지금 미국은 부정선거의 증거가 너무 많아서 바이든이 대통령되기는 커녕 감빵갈 기세다...  1.0    143
# 16   17  경악할만큼의 거대한 부정선거가 오래전부터 준비되어왔고 바이든, 민주당, 주류미디어,...  2.0    149
# 15   16  우리나라 국민들 너무나 개돼지들이다..대법원에서 재검표시한인 6개월을 훌쩍 넘겨도 ...  0.0    146
# 12   13  미국은 이미 청문회하고~ 경합주부터 해서 거이다 결과보류 판사들이 때렸던데..  결...  0.0    133
# 42   43  언론은 진실을 밝히기 위해 투쟁해야 하는데......왜 미국에서 발표되고 심리되는 ...  0.0    116
# 63   64  트럼프가 이기고 있고 아직 270석이 안됐을 뿐이고 증거들과 증인들이 넘쳐나고 있고...  0.0    142
# 41   42  투쟁은 개뿔이나. 그 날짜에 대선이 끝난다. 정부와 기레기들이 이상한 언론에서 기사...  0.0    101
# 39   40  트럼프 후보가 선거 결과를 12월 8일에 수용 할 것이다. 그는 선거인단 선거에서 ...  0.0     69
# 88   89  그렇다면 트럼프나 바이든이나 누가 대통령이 될 것인지를 물었다. 주님께서 응답하셨다...  0.0    130
# 7     8  기레기가 쓴 기사 내용만봐도 누가 이길건지 뻔히 알겠는데 어떻게 뻔한 거짓말을 할수...  0.0     95
#
#      본문/전체명사  본문/전체명사종류       자카드  nonset자카드     자카드명사  nonset자카드명사
# 18  0.520833   0.487179  0.117512   0.225806  0.092233     0.121359
# 16  0.304348   0.268293  0.112360   0.208989  0.050926     0.064815
# 15  0.275000   0.312500  0.106335   0.178733  0.048077     0.052885
# 12  0.404255   0.372093  0.099323   0.176072  0.075117     0.089202
# 42  0.451613   0.423077  0.098592   0.176056  0.054726     0.069652
# 63  0.274510   0.250000  0.096847   0.186937  0.050228     0.063927
# 41  0.566667   0.500000  0.093525   0.172662  0.060606     0.085859
# 39  0.705882   0.642857  0.085575   0.127139  0.047120     0.062827
# 88  0.250000   0.200000  0.084282   0.177677  0.024272     0.033981
# 7   0.350000   0.315789  0.076744   0.113953  0.030151     0.035176

# %%
df2 = pd.DataFrame(rated_comments, columns = ['댓글번호','댓글내용','답글수','pos길이',
                                              '본문/전체명사','본문/전체명사종류', 
                                              '자카드','nonset자카드',
                                              '자카드명사','nonset자카드명사'])

new_df2 = df2.sort_values(by='nonset자카드', ascending=False)

new_df2.head(10)

#new_df2
# Out:
#    댓글번호                                               댓글내용  답글수  pos길이  \
# 18   19  지금 미국은 부정선거의 증거가 너무 많아서 바이든이 대통령되기는 커녕 감빵갈 기세다...  1.0    143
# 16   17  경악할만큼의 거대한 부정선거가 오래전부터 준비되어왔고 바이든, 민주당, 주류미디어,...  2.0    149
# 63   64  트럼프가 이기고 있고 아직 270석이 안됐을 뿐이고 증거들과 증인들이 넘쳐나고 있고...  0.0    142
# 15   16  우리나라 국민들 너무나 개돼지들이다..대법원에서 재검표시한인 6개월을 훌쩍 넘겨도 ...  0.0    146
# 88   89  그렇다면 트럼프나 바이든이나 누가 대통령이 될 것인지를 물었다. 주님께서 응답하셨다...  0.0    130
# 12   13  미국은 이미 청문회하고~ 경합주부터 해서 거이다 결과보류 판사들이 때렸던데..  결...  0.0    133
# 42   43  언론은 진실을 밝히기 위해 투쟁해야 하는데......왜 미국에서 발표되고 심리되는 ...  0.0    116
# 41   42  투쟁은 개뿔이나. 그 날짜에 대선이 끝난다. 정부와 기레기들이 이상한 언론에서 기사...  0.0    101
# 83   84  바지사장 바이든이 진짜 당선 되었다 치더라도 민주당 자체에서 제거될겁니다 그 다음이...  1.0    122
# 39   40  트럼프 후보가 선거 결과를 12월 8일에 수용 할 것이다. 그는 선거인단 선거에서 ...  0.0     69
#
#      본문/전체명사  본문/전체명사종류       자카드  nonset자카드     자카드명사  nonset자카드명사
# 18  0.520833   0.487179  0.117512   0.225806  0.092233     0.121359
# 16  0.304348   0.268293  0.112360   0.208989  0.050926     0.064815
# 63  0.274510   0.250000  0.096847   0.186937  0.050228     0.063927
# 15  0.275000   0.312500  0.106335   0.178733  0.048077     0.052885
# 88  0.250000   0.200000  0.084282   0.177677  0.024272     0.033981
# 12  0.404255   0.372093  0.099323   0.176072  0.075117     0.089202
# 42  0.451613   0.423077  0.098592   0.176056  0.054726     0.069652
# 41  0.566667   0.500000  0.093525   0.172662  0.060606     0.085859
# 83  0.285714   0.212121  0.072235   0.135440  0.033019     0.066038
# 39  0.705882   0.642857  0.085575   0.127139  0.047120     0.062827

# %%
df2 = pd.DataFrame(rated_comments, columns = ['댓글번호','댓글내용','답글수','pos길이',
                                              '본문/전체명사','본문/전체명사종류', 
                                              '자카드','nonset자카드',
                                              '자카드명사','nonset자카드명사'])

new_df2 = df2.sort_values(by='자카드명사', ascending=False)

new_df2.head(10)

#new_df2
# Out:
#    댓글번호                                               댓글내용  답글수  pos길이  \
# 18   19  지금 미국은 부정선거의 증거가 너무 많아서 바이든이 대통령되기는 커녕 감빵갈 기세다...  1.0    143
# 12   13  미국은 이미 청문회하고~ 경합주부터 해서 거이다 결과보류 판사들이 때렸던데..  결...  0.0    133
# 41   42  투쟁은 개뿔이나. 그 날짜에 대선이 끝난다. 정부와 기레기들이 이상한 언론에서 기사...  0.0    101
# 42   43  언론은 진실을 밝히기 위해 투쟁해야 하는데......왜 미국에서 발표되고 심리되는 ...  0.0    116
# 16   17  경악할만큼의 거대한 부정선거가 오래전부터 준비되어왔고 바이든, 민주당, 주류미디어,...  2.0    149
# 63   64  트럼프가 이기고 있고 아직 270석이 안됐을 뿐이고 증거들과 증인들이 넘쳐나고 있고...  0.0    142
# 15   16  우리나라 국민들 너무나 개돼지들이다..대법원에서 재검표시한인 6개월을 훌쩍 넘겨도 ...  0.0    146
# 39   40  트럼프 후보가 선거 결과를 12월 8일에 수용 할 것이다. 그는 선거인단 선거에서 ...  0.0     69
# 66   67  연방총무처(조달청) "바이든 당선인정 보도는 가짜뉴스, 대통령 선거의 실제 승자는 ...  0.0     30
# 71   72  https://kr.theepochtimes.com/share/554053중국 관영...  0.0    133
#
#      본문/전체명사  본문/전체명사종류       자카드  nonset자카드     자카드명사  nonset자카드명사
# 18  0.520833   0.487179  0.117512   0.225806  0.092233     0.121359
# 12  0.404255   0.372093  0.099323   0.176072  0.075117     0.089202
# 41  0.566667   0.500000  0.093525   0.172662  0.060606     0.085859
# 42  0.451613   0.423077  0.098592   0.176056  0.054726     0.069652
# 16  0.304348   0.268293  0.112360   0.208989  0.050926     0.064815
# 63  0.274510   0.250000  0.096847   0.186937  0.050228     0.063927
# 15  0.275000   0.312500  0.106335   0.178733  0.048077     0.052885
# 39  0.705882   0.642857  0.085575   0.127139  0.047120     0.062827
# 66  0.555556   0.529412  0.044888   0.049875  0.046392     0.051546
# 71  0.296296   0.243902  0.066519   0.106430  0.046083     0.073733

# %%
df2 = pd.DataFrame(rated_comments, columns = ['댓글번호','댓글내용','답글수','pos길이',
                                              '본문/전체명사','본문/전체명사종류', 
                                              '자카드','nonset자카드',
                                              '자카드명사','nonset자카드명사'])

new_df2 = df2.sort_values(by='nonset자카드명사', ascending=False)

new_df2.head(10)

#new_df2
# Out:
#    댓글번호                                               댓글내용  답글수  pos길이  \
# 18   19  지금 미국은 부정선거의 증거가 너무 많아서 바이든이 대통령되기는 커녕 감빵갈 기세다...  1.0    143
# 12   13  미국은 이미 청문회하고~ 경합주부터 해서 거이다 결과보류 판사들이 때렸던데..  결...  0.0    133
# 41   42  투쟁은 개뿔이나. 그 날짜에 대선이 끝난다. 정부와 기레기들이 이상한 언론에서 기사...  0.0    101
# 71   72  https://kr.theepochtimes.com/share/554053중국 관영...  0.0    133
# 42   43  언론은 진실을 밝히기 위해 투쟁해야 하는데......왜 미국에서 발표되고 심리되는 ...  0.0    116
# 83   84  바지사장 바이든이 진짜 당선 되었다 치더라도 민주당 자체에서 제거될겁니다 그 다음이...  1.0    122
# 16   17  경악할만큼의 거대한 부정선거가 오래전부터 준비되어왔고 바이든, 민주당, 주류미디어,...  2.0    149
# 63   64  트럼프가 이기고 있고 아직 270석이 안됐을 뿐이고 증거들과 증인들이 넘쳐나고 있고...  0.0    142
# 39   40  트럼프 후보가 선거 결과를 12월 8일에 수용 할 것이다. 그는 선거인단 선거에서 ...  0.0     69
# 15   16  우리나라 국민들 너무나 개돼지들이다..대법원에서 재검표시한인 6개월을 훌쩍 넘겨도 ...  0.0    146
#
#      본문/전체명사  본문/전체명사종류       자카드  nonset자카드     자카드명사  nonset자카드명사
# 18  0.520833   0.487179  0.117512   0.225806  0.092233     0.121359
# 12  0.404255   0.372093  0.099323   0.176072  0.075117     0.089202
# 41  0.566667   0.500000  0.093525   0.172662  0.060606     0.085859
# 71  0.296296   0.243902  0.066519   0.106430  0.046083     0.073733
# 42  0.451613   0.423077  0.098592   0.176056  0.054726     0.069652
# 83  0.285714   0.212121  0.072235   0.135440  0.033019     0.066038
# 16  0.304348   0.268293  0.112360   0.208989  0.050926     0.064815
# 63  0.274510   0.250000  0.096847   0.186937  0.050228     0.063927
# 39  0.705882   0.642857  0.085575   0.127139  0.047120     0.062827
# 15  0.275000   0.312500  0.106335   0.178733  0.048077     0.052885

# %%
df3 = pd.DataFrame(similarity_comments, columns = ['댓글번호','댓글내용','답글수',
                                                   '코사인유사도',
                                                   '유클리디언','norm유클',
                                                   '맨해튼','norm맨해'])

new_df3 = df3.sort_values(by='코사인유사도', ascending=False)

new_df3
#df3

new_df3.head(10)
# Out:
#    댓글번호                                               댓글내용  답글수    코사인유사도  \
# 39   40  트럼프 후보가 선거 결과를 12월 8일에 수용 할 것이다. 그는 선거인단 선거에서 ...  0.0  0.156310
# 17   18  선거인단이 투표를 못하니까 트럼프 저렇게 말한다 거다 ㅋㅋㅋㅋㅋ지금 경합주 전부다 ...  0.0  0.108664
# 92   93                                     미합중국 대통령 조 바이든  1.0  0.104877
# 41   42  투쟁은 개뿔이나. 그 날짜에 대선이 끝난다. 정부와 기레기들이 이상한 언론에서 기사...  0.0  0.065820
# 11   12                               14일 이전에 바이든 뒤진다는 소리임  1.0  0.060642
# 22   23                                      바이든 당선 호소인읍소인  0.0  0.059638
# 66   67  연방총무처(조달청) "바이든 당선인정 보도는 가짜뉴스, 대통령 선거의 실제 승자는 ...  0.0  0.055213
# 91   92                   바이든 치지자도 아니지만 결과에 성복않는 또람프가이해불가.  1.0  0.054257
# 63   64  트럼프가 이기고 있고 아직 270석이 안됐을 뿐이고 증거들과 증인들이 넘쳐나고 있고...  0.0  0.051774
# 79   80                          추하다 추해 미국 역사상 오점으로 남을 대통령  0.0  0.049436
#
#        유클리디언    norm유클        맨해튼    norm맨해
# 39  1.298992  0.062759  18.908316  0.913534
# 17  1.335168  0.068820  18.656208  0.961612
# 92  1.338001  0.081595  15.979776  0.974496
# 41  1.366880  0.066056  19.782234  0.955994
# 11  1.370663  0.081189  16.541009  0.979775
# 22  1.371395  0.083661  16.126863  0.983810
# 66  1.374618  0.073777  18.061268  0.969360
# 91  1.375313  0.080444  16.755168  0.980028
# 63  1.377117  0.060144  22.516522  0.983384
# 79  1.378814  0.079871  16.922318  0.980262

# %%
df3 = pd.DataFrame(similarity_comments, columns = ['댓글번호','댓글내용','답글수',
                                                   '코사인유사도',
                                                   '유클리디언','norm유클',
                                                   '맨해튼','norm맨해'])

new_df3 = df3.sort_values(by='유클리디언', ascending=True)

new_df3
#df3

new_df3.head(10)
# Out:
#    댓글번호                                               댓글내용  답글수    코사인유사도  \
# 39   40  트럼프 후보가 선거 결과를 12월 8일에 수용 할 것이다. 그는 선거인단 선거에서 ...  0.0  0.156310
# 17   18  선거인단이 투표를 못하니까 트럼프 저렇게 말한다 거다 ㅋㅋㅋㅋㅋ지금 경합주 전부다 ...  0.0  0.108664
# 92   93                                     미합중국 대통령 조 바이든  1.0  0.104877
# 41   42  투쟁은 개뿔이나. 그 날짜에 대선이 끝난다. 정부와 기레기들이 이상한 언론에서 기사...  0.0  0.065820
# 11   12                               14일 이전에 바이든 뒤진다는 소리임  1.0  0.060642
# 22   23                                      바이든 당선 호소인읍소인  0.0  0.059638
# 66   67  연방총무처(조달청) "바이든 당선인정 보도는 가짜뉴스, 대통령 선거의 실제 승자는 ...  0.0  0.055213
# 91   92                   바이든 치지자도 아니지만 결과에 성복않는 또람프가이해불가.  1.0  0.054257
# 63   64  트럼프가 이기고 있고 아직 270석이 안됐을 뿐이고 증거들과 증인들이 넘쳐나고 있고...  0.0  0.051774
# 79   80                          추하다 추해 미국 역사상 오점으로 남을 대통령  0.0  0.049436
#
#        유클리디언    norm유클        맨해튼    norm맨해
# 39  1.298992  0.062759  18.908316  0.913534
# 17  1.335168  0.068820  18.656208  0.961612
# 92  1.338001  0.081595  15.979776  0.974496
# 41  1.366880  0.066056  19.782234  0.955994
# 11  1.370663  0.081189  16.541009  0.979775
# 22  1.371395  0.083661  16.126863  0.983810
# 66  1.374618  0.073777  18.061268  0.969360
# 91  1.375313  0.080444  16.755168  0.980028
# 63  1.377117  0.060144  22.516522  0.983384
# 79  1.378814  0.079871  16.922318  0.980262

# %%
df3 = pd.DataFrame(similarity_comments, columns = ['댓글번호','댓글내용','답글수',
                                                   '코사인유사도',
                                                   '유클리디언','norm유클',
                                                   '맨해튼','norm맨해'])

new_df3 = df3.sort_values(by='norm유클', ascending=True)

new_df3
#df3

new_df3.head(10)
# Out:
#    댓글번호                                               댓글내용  답글수    코사인유사도  \
# 63   64  트럼프가 이기고 있고 아직 270석이 안됐을 뿐이고 증거들과 증인들이 넘쳐나고 있고...  0.0  0.051774
# 16   17  경악할만큼의 거대한 부정선거가 오래전부터 준비되어왔고 바이든, 민주당, 주류미디어,...  2.0  0.047514
# 39   40  트럼프 후보가 선거 결과를 12월 8일에 수용 할 것이다. 그는 선거인단 선거에서 ...  0.0  0.156310
# 71   72  https://kr.theepochtimes.com/share/554053중국 관영...  0.0  0.042659
# 12   13  미국은 이미 청문회하고~ 경합주부터 해서 거이다 결과보류 판사들이 때렸던데..  결...  0.0  0.034880
# 88   89  그렇다면 트럼프나 바이든이나 누가 대통령이 될 것인지를 물었다. 주님께서 응답하셨다...  0.0  0.028668
# 18   19  지금 미국은 부정선거의 증거가 너무 많아서 바이든이 대통령되기는 커녕 감빵갈 기세다...  1.0  0.018017
# 83   84  바지사장 바이든이 진짜 당선 되었다 치더라도 민주당 자체에서 제거될겁니다 그 다음이...  1.0  0.003318
# 15   16  우리나라 국민들 너무나 개돼지들이다..대법원에서 재검표시한인 6개월을 훌쩍 넘겨도 ...  0.0  0.012464
# 41   42  투쟁은 개뿔이나. 그 날짜에 대선이 끝난다. 정부와 기레기들이 이상한 언론에서 기사...  0.0  0.065820
#
#        유클리디언    norm유클        맨해튼    norm맨해
# 63  1.377117  0.060144  22.516522  0.983384
# 16  1.380207  0.062063  21.399356  0.962255
# 39  1.298992  0.062759  18.908316  0.913534
# 71  1.383720  0.063286  21.345816  0.976274
# 12  1.389330  0.063510  21.609889  0.987847
# 88  1.393794  0.064724  21.119569  0.980728
# 18  1.401416  0.064884  21.370752  0.989445
# 83  1.411865  0.065003  21.644724  0.996537
# 15  1.405372  0.065132  21.389142  0.991279
# 41  1.366880  0.066056  19.782234  0.955994

# %%
df3 = pd.DataFrame(similarity_comments, columns = ['댓글번호','댓글내용','답글수',
                                                   '코사인유사도',
                                                   '유클리디언','norm유클',
                                                   '맨해튼','norm맨해'])

new_df3 = df3.sort_values(by='맨해튼', ascending=True)

new_df3
#df3

new_df3.head(10)
# Out:
#    댓글번호             댓글내용  답글수    코사인유사도     유클리디언    norm유클        맨해튼  \
# 59   60         어렵지않을까싶다  0.0  0.000000  1.414214  0.090606  15.608379
# 31   32    저널리즘이라곤없는받아쓰기  0.0  0.000000  1.414214  0.090606  15.608379
# 86   87          빙구 때  기  0.0  0.000000  1.414214  0.090606  15.608379
# 92   93   미합중국 대통령 조 바이든  1.0  0.104877  1.338001  0.081595  15.979776
# 74   75         희대의 얼가니ᆢ  0.0  0.000000  1.414214  0.088264  16.022593
# 29   30         어용언론임 ㅋㅋ  0.0  0.000000  1.414214  0.088264  16.022593
# 52   53         럼프형 힘내요!  0.0  0.000000  1.414214  0.088264  16.022593
# 27   28          기사가 개그?  0.0  0.000000  1.414214  0.088264  16.022593
# 22   23    바이든 당선 호소인읍소인  0.0  0.059638  1.371395  0.083661  16.126863
# 80   81  태극할배들 어쩌누? 꺼이꺼이  0.0  0.000000  1.414214  0.086547  16.340430
#
#       norm맨해
# 59  1.000000
# 31  1.000000
# 86  1.000000
# 92  0.974496
# 74  1.000000
# 29  1.000000
# 52  1.000000
# 27  1.000000
# 22  0.983810
# 80  1.000000

# %%
df3 = pd.DataFrame(similarity_comments, columns = ['댓글번호','댓글내용','답글수',
                                                   '코사인유사도',
                                                   '유클리디언','norm유클',
                                                   '맨해튼','norm맨해'])

new_df3 = df3.sort_values(by='norm맨해', ascending=True)

new_df3
#df3

new_df3.head(10)
# Out:
#    댓글번호                                               댓글내용  답글수    코사인유사도  \
# 39   40  트럼프 후보가 선거 결과를 12월 8일에 수용 할 것이다. 그는 선거인단 선거에서 ...  0.0  0.156310
# 41   42  투쟁은 개뿔이나. 그 날짜에 대선이 끝난다. 정부와 기레기들이 이상한 언론에서 기사...  0.0  0.065820
# 17   18  선거인단이 투표를 못하니까 트럼프 저렇게 말한다 거다 ㅋㅋㅋㅋㅋ지금 경합주 전부다 ...  0.0  0.108664
# 16   17  경악할만큼의 거대한 부정선거가 오래전부터 준비되어왔고 바이든, 민주당, 주류미디어,...  2.0  0.047514
# 66   67  연방총무처(조달청) "바이든 당선인정 보도는 가짜뉴스, 대통령 선거의 실제 승자는 ...  0.0  0.055213
# 61   62  미국 대통령 관련 뉴스 특 : 선동은 지들이 유튜브 찌라시 보고 당해놓고 자기들이 ...  1.0  0.039661
# 92   93                                     미합중국 대통령 조 바이든  1.0  0.104877
# 71   72  https://kr.theepochtimes.com/share/554053중국 관영...  0.0  0.042659
# 2     3  306명의 선거인단을 바이든이 확보했다고?현지에서 업데이트한거 보고 정확한 기사를 ...  6.0  0.042920
# 11   12                               14일 이전에 바이든 뒤진다는 소리임  1.0  0.060642
#
#        유클리디언    norm유클        맨해튼    norm맨해
# 39  1.298992  0.062759  18.908316  0.913534
# 41  1.366880  0.066056  19.782234  0.955994
# 17  1.335168  0.068820  18.656208  0.961612
# 16  1.380207  0.062063  21.399356  0.962255
# 66  1.374618  0.073777  18.061268  0.969360
# 61  1.385885  0.071882  18.787190  0.974445
# 92  1.338001  0.081595  15.979776  0.974496
# 71  1.383720  0.063286  21.345816  0.976274
# 2   1.383532  0.075193  17.981278  0.977263
# 11  1.370663  0.081189  16.541009  0.979775
